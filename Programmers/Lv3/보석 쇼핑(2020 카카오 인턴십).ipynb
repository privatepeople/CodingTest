# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/67258

# %%
from typing import List
from collections import defaultdict

def answer_compare(answer: List[int] = [0, float("inf")], new_answer: List[int] = [0, float("inf")]) -> List[int]:
    """정답 비교 함수

    Args:
        answer: 이전 정답, List[int, int]
        new_answer: 새로운 정답, List[int, int]

    Returns:
        최종 정답
    """
    order = (new_answer[1] - new_answer[0]) - (answer[1] - answer[0])
    if order < 0:
        return new_answer
    if order == 0 and new_answer[0] < answer[0]:
        return new_answer
    return answer

def solution(gems):
    n = len(gems)
    gem_kind = len(set(gems))
    current_dict = defaultdict(int)
    answer = [0, n]
    left, right = 0, -1

    while right != n - 1:
        while right < n - 1:
            right += 1
            current_dict[gems[right]] += 1
            if len(current_dict) == gem_kind:
                break

        if len(current_dict) == gem_kind:
            answer = answer_compare(answer, [left, right])

        while len(current_dict) == gem_kind:
            current_dict[gems[left]] -= 1
            if current_dict[gems[left]] == 0:
                del current_dict[gems[left]]
            left += 1
            if left <= right < n and len(current_dict) == gem_kind:
                answer = answer_compare(answer, [left, right])

    return [answer[0] + 1, answer[1] + 1]

# TestCase
print(solution(["DIA", "RUBY", "RUBY", "DIA", "DIA", "EMERALD", "SAPPHIRE", "DIA"]) == [3, 7])
print(solution(["AA", "AB", "AC", "AA", "AC"]) == [1, 3])
print(solution(["XYZ", "XYZ", "XYZ"]) == [1, 1])
print(solution(["ZZZ", "YYY", "NNNN", "YYY", "BBB"]) == [1, 5])
print(solution(["DIA", "EM", "EM", "RUB", "DIA"]) == [3, 5])
print(solution(["A", "A", "B"]) == [2, 3])
print(solution(["A", "A", "A", "B", "B"]) == [3, 4])
print(solution(["A"]) == [1, 1])
print(solution(["A", "B", "B", "B", "B", "B", "B", "C", "B", "A"]) == [8, 10])
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
