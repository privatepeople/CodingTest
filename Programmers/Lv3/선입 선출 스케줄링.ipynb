# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/12920

# %%
from typing import List

def solution(n: int, cores: List[int]) -> int:
    if n <= len(cores):
        return n

    n -= len(cores)
    left, right = 1, max(cores) * n
    while left < right:
        mid = left + (right - left) // 2
        works = sum(map(lambda core: mid // core, cores))

        if works < n:
            left = mid + 1
        else:
            right = mid

    work_hours = left
    last_works = [(work_hours - 1) // core for core in cores]
    remain_n = n - sum(last_works)

    for idx, core in enumerate(cores, start=1):
        if not (work_hours % core):
            remain_n -= 1

            if not remain_n:
                return idx

# TestCase
print(solution(6, [1, 2, 3]) == 2)
# Out:
# True
