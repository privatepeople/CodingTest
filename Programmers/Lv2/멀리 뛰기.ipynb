# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/12914

# %%
def solution(n: int) -> int:
    x, y = 1, 2
    for _ in range(n - 1):
        x, y = y, x + y
    return x % 1234567

# TestCase
print(solution(4) == 5)
print(solution(3) == 3)
# Out:
# True
# True
