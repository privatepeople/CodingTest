# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/42746

# %%
from typing import List
from functools import cmp_to_key

def number_sort(str1: str, str2: str) -> int:
    """두 문자열의 결합순서에 따른 비교정렬을 하는 함수"""
    s1, s2 = str1 + str2, str2 + str1
    return int(s1) - int(s2)


def solution(numbers: List[int]) -> str:
    numbers = list(map(str, numbers))
    return str(int(''.join(sorted(numbers, key=cmp_to_key(number_sort), reverse=True))))

# TestCase
print(solution([6, 10, 2]) == "6210")
print(solution([3, 30, 34, 5, 9]) == "9534330")
# Out:
# True
# True
