# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/138476?language=python3

# %%
from typing import List
from collections import Counter

def solution(k: int, tangerine: List[int]) -> int:
    answer = 0
    tangerine_count = Counter(tangerine).values()

    for val in sorted(tangerine_count, reverse=True):
        answer += 1
        k -= val
        if k <= 0:
            break

    return answer

# TestCase
print(solution(6, [1, 3, 2, 5, 4, 5, 2, 3]) == 3)
print(solution(4, [1, 3, 2, 5, 4, 5, 2, 3]) == 2)
print(solution(2, [1, 1, 1, 1, 2, 2, 2, 3]) == 1)
# Out:
# True
# True
# True
