# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/12900?language=python3

# %%
def solution(n: int) -> int:
    x, y = 1, 1
    for _ in range(n):
        x, y = y, x + y

    return x % 1000000007

# TestCase
print(solution(4) == 5)
# Out:
# True
# True
