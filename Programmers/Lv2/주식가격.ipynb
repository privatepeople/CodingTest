# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/42584?language=python3

# %%
from typing import List

def solution(prices: List[int]) -> List[int]:
    stack, n = [], len(prices)
    answer = [0] * n

    for i in range(n):
        while stack and stack[-1][1] > prices[i]:
            past, price = stack.pop()
            answer[past] = i - past
        stack.append((i, prices[i]))

    for past, price in stack:
        answer[past] = n - 1 - past

    return answer

# TestCase
print(solution([1, 2, 3, 2, 3]) == [4, 3, 1, 1, 0])
# Out:
# True
# True
