# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/60057?language=python3

# %%
def solution(s: str) -> int:
    n = len(s)
    answer = n

    for p in range(1, n // 2 + 1):
        strs, idx, cnt = '', 0, 0
        s_zip = s[:p]
        while idx < n:
            while s_zip == s[idx:idx + p]:
                cnt += 1
                idx += p
            if cnt > 1:
                strs += str(cnt)
            strs += s_zip
            s_zip, cnt = s[idx:idx + p], 0

        answer = min(answer, len(strs))

    return answer

# TestCase
print(solution("aabbaccc") == 7)
print(solution("ababcdcdababcdcd") == 9)
print(solution("abcabcdede") == 8)
print(solution("abcabcabcabcdededededede") == 14)
print(solution("xababcdcdababcdcd") == 17)
# Out:
# True
# True
# True
# True
# True
