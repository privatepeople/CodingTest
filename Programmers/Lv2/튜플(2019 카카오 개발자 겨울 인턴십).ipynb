# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/64065

# %%
from typing import List
from collections import Counter
import re

def solution(s: str) -> List[int]:
    tuple_count = Counter(re.findall(r'\d+', s)).most_common()
    return [int(k) for k, v in tuple_count]

# TestCase
print(solution("{{2},{2,1},{2,1,3},{2,1,3,4}}") == [2, 1, 3, 4])
print(solution("{{1,2,3},{2,1},{1,2,4,3},{2}}") == [2, 1, 3, 4])
print(solution("{{20,111},{111}}") == [111, 20])
print(solution("{{123}}") == [123])
print(solution("{{4,2,3},{3},{2,3,4,1},{2,3}}") == [3, 2, 4, 1])
# Out:
# True
# True
# True
# True
# True
