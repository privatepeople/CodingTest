# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/62048

# %%
from math import gcd

def solution(w: int, h: int) -> int:
    return w * h - (w + h - gcd(w, h))

# TestCase
print(solution(8, 12) == 80)
# Out:
# True
# True
