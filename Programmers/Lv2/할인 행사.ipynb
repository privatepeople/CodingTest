# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/131127?language=python3

# %%
from typing import List
from collections import Counter

def solution(want: List[str], number: List[int], discount: List[str]) -> int:
    answer = 0
    shopping_dict = dict(zip(want, number))

    for i in range(len(discount) - 9):
        if shopping_dict == Counter(discount[i:i + 10]):
            answer += 1

    return answer

# TestCase
print(solution(["banana", "apple", "rice", "pork", "pot"], [3, 2, 2, 2, 1], ["chicken", "apple", "apple", "banana", "rice", "apple", "pork", "banana", "pork", "rice", "pot", "banana", "apple", "banana"]) == 3)
print(solution(["apple"], [10], ["banana", "banana", "banana", "banana", "banana", "banana", "banana", "banana", "banana", "banana"]) == 0)
# Out:
# True
# True
