# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/120897

# %%
from typing import List
from math import sqrt, ceil

def solution(n: int) -> List[int]:
    num = ceil(sqrt(n))
    answer = [] if n // num != num else [num]

    for i in range(1, num):
        q, r = divmod(n, i)
        if r == 0:
            answer.extend([i, q])

    return sorted(answer)

# TestCase
print(solution(24) == [1, 2, 3, 4, 6, 8, 12, 24])
print(solution(29) == [1, 29])
# Out:
# True
# True
