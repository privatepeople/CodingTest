# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/181830

# %%
from typing import List

def solution(arr: List[List[int]]) -> List[List[int]]:
    m, n = len(arr), len(arr[0])

    if m > n:
        return [i + [0] * (m - n) for i in arr]
    elif m < n:
        return arr + [[0] * n for i in range(n - m)]
    else:
        return arr

# TestCase
print(solution([[572, 22, 37], [287, 726, 384], [85, 137, 292], [487, 13, 876]]) == [[572, 22, 37, 0], [287, 726, 384, 0], [85, 137, 292, 0], [487, 13, 876, 0]])
print(solution([[57, 192, 534, 2], [9, 345, 192, 999]]) == [[57, 192, 534, 2], [9, 345, 192, 999], [0, 0, 0, 0], [0, 0, 0, 0]])
print(solution([[1, 2], [3, 4]]) == [[1, 2], [3, 4]])
# Out:
# True
# True
