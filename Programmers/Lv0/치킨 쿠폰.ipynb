# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/120884

# %%
def solution(chicken: int) -> int:
    return (max(chicken, 1) - 1) // 9

# TestCase
print(solution(100) == 11)
print(solution(1081) == 120)
# Out:
# True
# True
