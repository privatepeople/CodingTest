# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/181880

# %%
from typing import List

def solution(num_list: List[int]) -> int:
    return sum(len(bin(i)) - 3 for i in num_list)

# TestCase
print(solution([12, 4, 15, 1, 14]) == 11)
# Out:
# True
# True
