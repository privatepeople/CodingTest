# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/120864

# %%
import re

def solution(my_string: str) -> int:
    return sum(int(x) for x in re.findall(r'[0-9]+', my_string))

# TestCase
print(solution("aAb1B2cC34oOp") == 37)
print(solution("1a2b3c4d123Z") == 133)
# Out:
# True
# True
