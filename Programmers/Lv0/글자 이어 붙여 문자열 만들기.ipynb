# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/181915

# %%
from typing import List

def solution(my_string: str, index_list: List[int]) -> str:
    answer = []

    for i in index_list:
        answer.append(my_string[i])

    return ''.join(answer)

# TestCase
print(solution("cvsgiorszzzmrpaqpe", [16, 6, 5, 3, 12, 14, 11, 11, 17, 12, 7]) == "programmers")
print(solution("zpiaz", [1, 2, 0, 0, 3]) == "pizza")
# Out:
# True
# True
