# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/120861

# %%
from typing import List

def solution(keyinput: List[str], board: List[int]) -> List[int]:
    x_lim, y_lim = board[0] // 2, board[1] // 2
    move = {'left': (-1, 0), 'right': (1, 0), 'up': (0, 1), 'down': (0, -1)}
    x, y = 0, 0

    for k in keyinput:
        dx, dy = move[k]
        if abs(x + dx) <= x_lim and abs(y + dy) <= y_lim:
            x, y = x + dx, y + dy

    return [x, y]

# TestCase
print(solution(["left", "right", "up", "right", "right"], [11, 11]) == [2, 1])
print(solution(["down", "down", "down", "down", "down"], [7, 9]) == [0, -4])
# Out:
# True
# True
