# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/181894

# %%
from typing import List

def solution(arr: List[int]) -> List[int]:
    if 2 in arr:
        two_start = arr.index(2)
        two_end = arr[::-1].index(2)
        return arr[two_start:len(arr) - two_end]
    else:
        return [-1]

# TestCase
print(solution([1, 2, 1, 4, 5, 2, 9]) == [2, 1, 4, 5, 2])
print(solution([1, 2, 1]) == 	[2])
print(solution([1, 1, 1]) == 	[-1])
print(solution([1, 2, 1, 2, 1, 10, 2, 1]) == 	[2, 1, 2, 1, 10, 2])
# Out:
# True
# True
# True
# True
