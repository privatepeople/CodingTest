# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/42576?language=python3

# %%
from typing import List
from collections import Counter

def solution(participant: List[str], completion: List[str]) -> str:
    answer = Counter(participant) - Counter(completion)
    return list(answer.keys())[0]

# TestCase
print(solution(["leo", "kiki", "eden"], ["eden", "kiki"]) == "leo")
print(solution(["marina", "josipa", "nikola", "vinko", "filipa"], ["josipa", "filipa", "marina", "nikola"]) == "vinko")
print(solution(["mislav", "stanko", "mislav", "ana"], ["stanko", "ana", "mislav"]) == "mislav")
# Out:
# True
# True
# True
