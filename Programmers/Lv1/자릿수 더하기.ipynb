# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/12931?language=python3

# %%
def solution(n: int) -> int:
    return sum(map(int, str(n)))

# TestCase
print(solution(123) == 6)
print(solution(987) == 24)
# Out:
# False
# False
