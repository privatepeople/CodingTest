# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/42840?language=python3

# %%
from typing import List
from itertools import cycle

def solution(answers: List[int]) -> List[int]:
    student_list = [cycle([1, 2, 3, 4, 5]),
                   cycle([2, 1, 2, 3, 2, 4, 2, 5]),
                   cycle([3, 3, 1, 1, 2, 2, 4, 4, 5, 5])]
    scores = [0, 0, 0]
    answer = []

    for val in answers:
        for student in range(3):
            if next(student_list[student]) == val:
                scores[student] += 1

    max_answer = max(scores)
    for i, val in enumerate(scores, start=1):
        if val == max_answer:
            answer.append(i)

    return answer

# TestCase
print(solution([1, 2, 3, 4, 5]) == [1])
print(solution([1, 3, 2, 4, 2]) == [1, 2, 3])
# Out:
# False
# False
