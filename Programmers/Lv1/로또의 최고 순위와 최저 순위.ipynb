# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/77484?language=python3

# %%
from typing import List

def solution(lottos: List[int], win_nums: List[int]) -> List[int]:
    rank_dict = {6: 1, 5: 2, 4: 3, 3: 4, 2: 5, 1: 6, 0: 6}
    win_nums = set(win_nums)
    answer, cnt = 0, lottos.count(0)

    for x in lottos:
        if x in win_nums:
            answer += 1

    return [rank_dict[answer + cnt], rank_dict[answer]]

# TestCase
print(solution([44, 1, 0, 0, 31, 25], [31, 10, 45, 1, 6, 19]) == [3, 5])
print(solution([0, 0, 0, 0, 0, 0], [38, 19, 20, 40, 15, 25]) == [1, 6])
print(solution([45, 4, 35, 20, 3, 9], [20, 9, 3, 45, 4, 35]) == [1, 1])
# Out:
# False
# False
