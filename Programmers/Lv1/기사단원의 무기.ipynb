# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/136798?language=python3

# %%
def solution(number: int, limit: int, power: int) -> int:
    number_list = [1] * (number + 1)

    for i in range(2, number + 1):
        for j in range(i, number + 1, i):
            number_list[j] += 1

    return sum([i if i <= limit else power for i in number_list[1:]])

# TestCase
print(solution(5, 3, 2) == 10)
print(solution(10, 3, 2) == 21)
# Out:
# False
# False
