# %% [markdown]
# 문제 출처 : https://school.programmers.co.kr/learn/courses/30/lessons/86491?language=python3

# %%
from typing import List
from math import inf

def solution(sizes: List[List[int]]) -> int:
    w = h = -inf

    for a, b in sizes:
        if b > a:
            a, b = b, a
        w = max(w, a)
        h = max(h, b)

    return w * h

# TestCase
print(solution([[60, 50], [30, 70], [60, 30], [80, 40]]) == 4000)
print(solution([[10, 7], [12, 3], [8, 15], [14, 7], [5, 15]]) == 120)
print(solution([[14, 4], [19, 6], [6, 16], [18, 7], [7, 11]]) == 133)
# Out:
# False
# False
